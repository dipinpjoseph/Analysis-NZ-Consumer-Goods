# %%
library(tidyverse)
library(readxl)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.1     v purrr   0.3.2
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   0.8.3     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
#setting the file name
agri_file <- "ag-1areas-hect-farm07.xls"

# %%
agri_file %>%
    read_excel(sheet = "Area in hectares by farm type", range = 'A7:J36', col_names = c("Farm_Type", "Grassland", "Tussock_Danthonia", "Grain_Seed", "Horticultural", "Exotic_Trees", "Mature_Bush", "NativeScrub", "Other_Land", "Tota_Land")) -> table_1_untidy

table_1_untidy
# Out:
#    Farm_Type                                        Grassland Tussock_Danthonia
# 1  A0111  Nursery production (under cover)          227       C
# 2  A0112  Nursery production (outdoors)             3843      88
# 3  A0113  Turf growing                              C         -
# 4  A0114  Floriculture production (under cover)     721       C
# 5  A0115  Floriculture production (outdoors)        846       C
# 6  A0121  Mushroom growing                          C         -
# 7  A0122  Vegetable growing (under cover)           2638      -
# 8  A0123  Vegetable growing (outdoors)              34030     369
# 9  A0131  Grape growing                             14921     1970
# 10 A0132  Kiwifruit growing                         6970      31
# 11 A0133  Berry fruit growing                       2264      C
# 12 A0134  Apple and pear growing                    3874      C
# 13 A0135  Stone fruit growing                       2458      321
# ...

# %%
table_1_untidy %>%
    replace(table_1_untidy == "-", 0)%>%
    replace(table_1_untidy == "C", 0) -> table_1_tidy

table_1_tidy
# Out:
#    Farm_Type                                        Grassland Tussock_Danthonia
# 1  A0111  Nursery production (under cover)          227       0
# 2  A0112  Nursery production (outdoors)             3843      88
# 3  A0113  Turf growing                              0         0
# 4  A0114  Floriculture production (under cover)     721       0
# 5  A0115  Floriculture production (outdoors)        846       0
# 6  A0121  Mushroom growing                          0         0
# 7  A0122  Vegetable growing (under cover)           2638      0
# 8  A0123  Vegetable growing (outdoors)              34030     369
# 9  A0131  Grape growing                             14921     1970
# 10 A0132  Kiwifruit growing                         6970      31
# 11 A0133  Berry fruit growing                       2264      0
# 12 A0134  Apple and pear growing                    3874      0
# 13 A0135  Stone fruit growing                       2458      321
# ...

# %%
sum(is.na(table_1_tidy))
# Out:
# [1] 0
